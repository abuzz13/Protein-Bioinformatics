# %% [markdown]
# #### Challenge Project Protein - Nanog: 2vi6

# %% [markdown]
# ##### Group Members: Amanda Busswitz, EJ Mablekos, and Kinal Patel

# %% [markdown]
# # Introduction of Protein
#
#     The transcription factor Nanog is an upstream regulator, this proteins is a key determinant of pluripotency in embryonic stem cells. Nanog binds to many different elements upon hundreds of target genes and thus regulates their expression, however the regulation is of an unknown mechanism. This protein contains a homeodomain (HD) in which the crystal structure has been derived, researchers have analyzed it's interactions with specific DNA elements, one of which is derived from the Tcf3 promoter. Researchers have discovered two aminio acid pairs which are unique among homeodomain sequences, appear to affect nonspecific DNA recognition all while maintaining the integrity of the structural scaffolding in the HD. To deterrmine and analyze the selective DNA recognition by Nanog, the researchers in a paper by Jauch, R. et al. (2008) from PDB, they performed electrophoretic mobility shift assays using modified DNA binding sites, ascertaining Nanog HD preferentially binds to the TAAT(G/T)(G/T) motif. Overall, with structural and functional elements investigated and analyzed, it has been established Nanog is considered to be a distant member of a Q50-type HD, with sizable variation at the sequence level.
#
#     Reference:
#
#     Ralf Jauch, Calista Keow Leng Ng, Kumar Singh Saikatendu, Raymond C. Stevens, Prasanna R. Kolatkar, Crystal Structure and DNA Binding of the Homeodomain of the Stem Cell Transcription Factor Nanog, Journal of Molecular Biology, Volume 376, Issue 3, 2008, Pages 758-770, ISSN 0022-2836, https://doi.org/10.1016/j.jmb.2007.11.091.

# %%
# %%HTML
# <iframe width = "1000" height = "900" src="https://www.rcsb.org/structure/2VI6" frameborder = "0" allowfullscreen></iframe>
# Out:
# <iframe width = "1000" height = "900" src="https://www.rcsb.org/structure/2VI6" frameborder = "0" allowfullscreen></iframe>

# %% [markdown]
# #### Challenge Question:
# You are studying the importance of a particular transcription factor X in X in self renewal of mouse and human embryonic stem cells. You have wild type cultured stem cells and another set of cells where transcription factor X can be knocked down. A colleague down the corridor has carried out a transcriptomics study for you and assures you that there are a few very important changes in the transcriptome of the cells when they are harvested after knockdown of the transcription factor, when compared with the wild type.
#
# You plan to carry out an experiment to answer the following question: Which proteins show a statistically significant change in expression upon knockdown of transcription factor X?

# %% [markdown]
# #### What is the aim of the study?
# Our goal is to  validate findings of the transcriptomics study. We will use quantitative methods to determine which proteins are differentially translated based on knockdown of transcription factors of human and mouse models in wild type and TF affected cells. This will help us to identify proteins that are regulated by TF X.

# %% [markdown]
# #### In this experiment what constitutes a biological and technical replicate? Do you have access to both? Which quantitation method you chose and why?
# Biological replicates will include all replicates available from transcriptomics study. As our colleagues are convinced of differential expression at the transcript level, we are assuming they have sufficient biological replicates to make such claims. We will have four cell types:
#     Mouse WT
#     Mouse KD
#     Human WT
#     Human KD
#
# Technical replicates will be separate samples taken from each cell line and run through our full experimental procedure. We will introduce technical replicates to control for technical effects.
#
# We chose to perform LC-MS/MS based on the ability to detect quantification of expression levels. Further, these results will be analyzed using statistical tests such as empirical Bayes moderated T-tests using limma.
# #### Definition of Technical Replicates:
#     Technical replicates are repeated measurements of the same sample that demonstrate the variability of the protocol. Technical replicates are important because they address the reproducibility of the assay or technique; however, they do not address the reproducibility of the effect or event that you are studying. Rather, they indicate whether your measurements are scientifically robust or noisy and how large the measured effect must be in order to stand out above the background noise. Examples may include loading multiple lanes with each sample on the same blot, running multiple blots in parallel, or repeating the blot with the same samples on different days.

# %% [markdown]
# #### At which point in the protocol will you combine your samples to be compared (e.g. not at all for LFQ)? Which point of your protocol do you consider to have the most technical variability?
# Will not combine our results as we are pursuing label free DIA. Samples will be run in parallel and kept separate throughout the comparison. It will be important to add control proteins so we can normalize the results across the different runs.
#
# Where we could see the most technical variability is possibly the comparison between multiple runs in parallel.

# %% [markdown]
# #### Is technical variability likely to outweigh biological variability?
# Inherent biological variability - build into experimental design -> won’t have wide biological variability
#
# Technical variability will be due to differences introduced by our procedure. It will be important to correct based on control genes and normalization methods so we can compare expression across runs.

# %% [markdown]
# #### What could go right/wrong with your pilot experiment (hypothetical)? Which visualizations will you use to check that the pilot experiment worked? Are there any effects in the data that will require normalization?
# A risk is that too much difference within technical replicates will invalidate too much data to allow us to perform the analysis with high confidence.
#
# Correlations of mean expression across cell lines will identify outliers.
#
# We can use a program called MASIC in order to help visualize LC-MS/LC. MASIC is able to quantify peptide abundances as well as elution times of LC. This program uses an algorithm in order to create mass specific ion chromatograms via datasets, and it also has an interactive browser available to visualize and examine the results (Monroe et al., 2008).
#
# Normalization will be critical to compare expression levels across different LC-MS/MS runs.

# %% [markdown]
# #### How can you work out which point your protocol is most variable?
# By comparing variation in expression level across technical replicates and biological replicates.
#
# We should see less variation across technical replicates once data is normalized. If there is variability in technical replicates, then we can change the methods in order to reduce variability. This can be done by altering variables, i.e., reagents.

# %% [markdown]
# #### What would you change about your pilot experiment?
# We may need additional biological replicates.
#
# A higher replicate count will allow us to measure for less of a fold change.

# %% [markdown]
# #### How many replicates do you think you might need, 3 per condition, 10 per condition, 1000s per condition?
# We will enrich our biological replicates with technical replicates to a count sufficient to offer 95% confidence and 80% power of a 2x fold change, corrected using FDR procedure. This will likely be between 5-20 samples of each cell type (Oberg, 2009)

# %% [markdown]
# Hypothesis:
# Unlike the wild-type (WT) samples, the mutant samples (Knock-out for transcription factor X) will contain proteins with differential expression, as they are regulated by transcription factor X.
#
# Samples:
# 1. 	WT mice cells, containing normal TF X
# 2. 	Mutant mice cells, containing Knock-out TF X
# 3. 	WT human cells, containing normal TF X
# 4. 	Mutant human cells, containing Knock-out TF X

# %% [markdown]
# #### Procedure Outline:
#
# Build separate MS databases for mouse and human samples. Include genes identified as differentially expressed and non-differentially expressed, control proteins, and a sufficient amount of decoy/background proteins.
#
# ↓
#
# Culture the embryonic stem cells using a growth factor medium
#
# ↓
#
# Prepare samples for MS analysis – using a Nuclear Extract Kit, utilizing buffers with protease and phosphatase inhibitors
#
# ↓
#
# Denature proteins with urea
#
# ↓
#
# Separate peptides using isoelectric focusing and perform fractionation
#
# ↓
#
# Add control proteins to sample to allow for comparison across runs
#
# ↓
#
# Perform LC-MS/MS on the peptide solution
#
# ↓
#
# Analyze using MaxQuant suite algorithms to search protein database and obtain expression levels
#
# ↓
#
# Differential expression measured using empirical Bayes moderated T-tests via limma
#
# ↓
#
# P-values corrected based on the multiple hypothesis testing using Benjamin-Hochberg method

# %% [markdown]
# #### LC-MS Spectra Results:
# We will have the following spectra outputs, for the following:
# Mouse WT
# Mouse KD
# Human WT
# Human KD
# Once the LC-MS is performed, the spectra will display the results for the wild-type and mutant groups. After comparing the peaks on both spectras, one can identify the differentially expressed proteins by looking at the change in magnitude as well as location of the corresponding peaks. Then, the peaks can be observed alone in order to figure out the proteins. As mentioned before, we can use MASIC in order to assist with the analysis and visualizations of the spectras. Then, we can use R-Studio and R packages for any required statistical analyses.

# %% [markdown]
# ### Need to Knows

# %% [markdown]
# #### 1.How can we use calculated global and local validation for all-atom contacts, covalent geometry, and conformation to identify the parameters of Nanog, helping to assign secondary structure characteristics?
#
# a.	Using the parameters from the Ramachandran plot analysis, what can this to infer about the protein?
#
# b.	What can the Ramachandran plot itself describe about the secondary structure of Nanog?
#
# c.	How can the angles from phi and psi generated in the analysis help identify the structure and its backbone?
#
# d.	How does bonding length and type assist in determining secondary structure?

# %% [markdown]
#     To do this step of our 'Need to Knows', I was able to locate a GitHub repository in which the user is walked through first determining how many chains are in their protein, the different amnino acids and their distribution within the protein. Following that, is determining the bond angles of the protein and making a Ramachandran plot to fully help to determine what the secondary structures are of a protein.
#         The github repositry below:
#
#     https://github.com/weisscharlesj/BiopythonRamachandran
#
#     Walk through the tutorial using a protein of interest to determine it's, chains, amino acids, and bonding angle, building a Ramachandran Plot.

# %% [markdown]
# # Bond Angles and Ramachandran Plots
# In this Jupyter notebook, you will be introduced to measuring the angles and dihedral angles along the backbond of peptide chains. The goals of this notebook are to:
#
# Measure angles and dihedral angles using biopython
# Examine angle distributions using histogram plots
# Generate Ramachandran plots by multiple plotting methods
# Dihedral angles are torsional angles formed by four adjacent atoms. There are three types of dihedral angles along the peptide backbond designated wiht phi ( 𝜙 ), psi ( 𝜓 ), and omega ( 𝜔 ) as shown below. These angles typically fall within specific ranges due to steric repulsion and bond order. In this notebook, we will explore these typical ranges.

# %%
from IPython.display import Image
Image("tripeptide.png", width=400)

# %% [markdown]
# Using the below code, import the needed libraries to run the PDB file and visualize.

# %%
import Bio.PDB
from Bio.PDB.vectors import calc_dihedral, calc_angle

import matplotlib.pyplot as plt
# %matplotlib inline
import os

import warnings
from Bio import BiopythonWarning
warnings.simplefilter('ignore', BiopythonWarning)

# %%
parser = Bio.PDB.PDBParser()
structure = parser.get_structure('2vi6', '2vi6.pdb')

# %% [markdown]
# ##  <font color = 545AA7> Examining Amino Acid Frequency and Structure of the Data </font>
#
# ### <Font color = 545aa7> All Amino Acids in Protein </font>
#
# Next, look at and visualize the amino acid residue distribution in the protein. Below is code to run that iterates through the peptides and adds each amino acid residue identity to a list called `amino_acids`.

# %%
protein_model = structure[0]

for chain in protein_model:
    print(chain)
# Out:
# <Chain id=A>
# <Chain id=B>
# <Chain id=C>
# <Chain id=D>
# <Chain id=E>
# <Chain id=F>
# <Chain id=G>
# <Chain id=H>

# %%
chain_A = structure[0]['A']
res = chain_A[8]
res
# Out:
# <Residue PHE het=  resseq=8 icode= >

# %%
res.get_unpacked_list()
# Out:
# [<Atom N>,
#  <Atom CA>,
#  <Atom C>,
#  <Atom O>,
#  <Atom CB>,
#  <Atom CG>,
#  <Atom CD1>,
#  <Atom CD2>,
#  <Atom CE1>,
#  <Atom CE2>,
#  <Atom CZ>]

# %%
def get_aa(file):
    '''Accepts a PDB files name (string) and returns a list of residues
    that occur in a peptide.
    
     >>> ('1abc.pdb') -> ['GLY', 'ALA', 'LYS']
    '''

    amino_acids = []  # empty list to add the amino acids to

    parser = Bio.PDB.PDBParser()
    structure = parser.get_structure('2vi6', '2vi6.pdb')
    pp = Bio.PDB.PPBuilder().build_peptides(structure[0])

    # go through each chain and residue and append the amino acid identity to the list
    for chain in pp:
        for res in chain:
            res_name = res.get_resname()
            amino_acids.append(res_name)
            
    return amino_acids

# %%
amino_acids = get_aa('2vi6.pdb')

# %% [markdown]
# ### <font color = F28500> Visualization Using a countplot() </font>
#
# Next, to visualize the above data use the **seaborn** plotting library's `sns.coutplot()` function. This plotting function takes in the data and tallies the number of occurances of each value in the data. In this case, the data are stored in the variable `sense`.

# %%
import seaborn as sns

sns.countplot(x=amino_acids, color='C00')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Measure Single Peptide Angles
# The Bio.PDB.vectors module of biopython contains two functions called calc_angle() and calc_dihedral() for calculating conventional angles or dihedral angles, respecitely, along the backbond of a peptide. These function take the vector coordinates (xyz) of the three or four atoms that define the angle or dihedral angle.
#
# calc_angle(<vector>, <vector>, <vector>)
#
# calc_dihedral(<vector>, <vector>, <vector>, <vector>)
# The vectors can be otained from the residues using the get_vector() function.

# %% [markdown]
# ##### Next, we will obtain the coordinate vectors for the carbon, nitrogen, and  𝛼 -carbon of an amino acid residue and attach them to variables N, CA, and C, respectively. This is done by identifying the specific atom and using the get_vector() function as described in the previous Jupyter notebook.
#
# Finally, these three vectors are fed into the calc_angle() function which returns the angle in radians.

# %%
C = res['C'].get_vector()
N = res['N'].get_vector()
CA = res['CA'].get_vector()

ang = calc_angle(N, CA, C)
ang
# Out:
# 1.9572855666217004

# %% [markdown]
# # Find Angle in Degrees
# Copy and paste the code from the above code cell and modify it to find the angle of the C 𝛼 -C-O bond. The oxygen in the aminoacid residue is designated by ['O'].
#
# convert the output from radiants  →  degrees.
#
# 𝑑𝑒𝑔𝑟𝑒𝑒𝑠=𝑟𝑎𝑑𝑖𝑎𝑛𝑠×180𝜋

# %%
C = res['C'].get_vector()
CA = res['CA'].get_vector()
O = res['O'].get_vector()

ang = calc_angle(CA, C, O)
ang
# Out:
# 2.112407590476564

# %%
ang * (180 / 3.14)
# Out:
# 121.09342875343359

# %% [markdown]
# # Examine Distributions of Angles
# Let's now examine the distribution of the omega (𝜔) bond angles using a histogram plot. In the code cell below, there is code that defines the Python function get_omega() you can use to measure all the omega dihedral angles.

# %%
# Run this cell to define a function you can use in subsequent cells

def get_abs_omega(file):
    """Return list of absolute value omega dihedral angles in radians"""  
    omega_list = []
    parser = Bio.PDB.PDBParser()
    structure = parser.get_structure('protein', file)
    pp = Bio.PDB.PPBuilder().build_peptides(structure[0])
    for chain in pp:
        for res in range(0, len(chain) - 1):
            try:
                # get vectors for this peptide and the N from the subsequent peptide
                CA = chain[res]['CA'].get_vector()
                C = chain[res]['C'].get_vector()
                N_next = chain[res + 1]['N'].get_vector()
                C_next = chain[res + 1]['CA'].get_vector()
                omega = calc_dihedral(CA, C, N_next, C_next) * (180 / 3.14159)
                omega_list.append(abs(omega))
            except KeyError:
                continue
    return omega_list

# %% [markdown]
# # Plot Omega Angle Distribution
# Run the get_abs_omega() function below for the 6x8j.pdb protein. You will also want to assign this list of angles to a variable for later use.
# Plot the distribution of omega angles using the plt.hist() histogram plot function. See the first Jupyter notebook if you need review.
# What do you notice about the distribution? What is the strucutral reason for this? Write you answer in a markdown cell below. Hint: the omega angle is centered on the peptide amide bond.

# %%
omega = get_abs_omega('2vi6.pdb')

# %%
plt.hist(omega, bins=10, edgecolor='black')
plt.show()

# %%
omega = []

import os
path, _ = os.path.split(os.getcwd())
top80 = os.path.join(path, 'Top80')

for file in os.listdir(top80):
    if file.endswith('pdb'):
        omega.extend(get_abs_omega(os.path.join(top80,file)))

# %%
plt.hist(omega, bins=100)
plt.show()

# %% [markdown]
# # Ramachandran Plots from Single Protein
# A Ramachandran plot is a 2D plot of the psi ( 𝜓 ) versus the phi ( 𝑝ℎ𝑖 ) dihedral angles. Below is a function that takes the file name of a PDB file and returns two lists: a list of phi and and list of psi angles.
#
# e.g., ramachandran('1abc.pdb') -> [phi], [psi]

# %%
def ramachandran(PDB):
    """Accepts a PDB file name (string) and returns two lists of phi and psi angles, respectively."""
    parser = Bio.PDB.PDBParser()
    structure = parser.get_structure('protein', PDB)
    polypeptide = Bio.PDB.PPBuilder().build_peptides(structure[0])
    
    phi = []
    psi = []

    for strand in polypeptide:
        phipsi = strand.get_phi_psi_list()
        for point in phipsi:
            try:
                phi_point = point[0] * (180 / 3.14159)
                psi_point = point[1] * (180 / 3.14159)
                phi.append(phi_point)
                psi.append(psi_point)
            except TypeError:
                pass
    
    return phi, psi

# %%
phi, psi = ramachandran('2vi6.pdb')

plt.scatter(phi, psi)
plt.xlabel('phi $\phi$, degrees')
plt.ylabel('psi $\psi$, degrees')
# Out:
# Text(0, 0.5, 'psi $\\psi$, degrees')

# %% [markdown]
# Finally, optionally you can combine the two lists of amino acids and plot them in the same plot to better see how the occurance of the amino acids appear at the start of different secondary structures.

# %%
import pandas as pd

#df_aa = pd.DataFrame([general, len(general) *['general']]).transpose()
df_hel = pd.DataFrame([helix_start, len(helix_start) *['helix_start']]).transpose()
df_beta = pd.DataFrame([sheet_start, len(sheet_start) *['sheet_start']]).transpose()

df = pd.concat((df_hel, df_beta))
df.columns = ['amino_acid', 'location']

df
# Out:
#      amino_acid     location
# 0           SER  helix_start
# 1           SER  helix_start
# 2           ASN  helix_start
# 3           GLU  helix_start
# 4           ASP  helix_start
# ...         ...          ...
# 1726        THR  sheet_start
# 1727        VAL  sheet_start
# 1728        ASN  sheet_start
# 1729        TYR  sheet_start
# 1730        PHE  sheet_start
#
# [3279 rows x 2 columns]

# %%
sns.countplot(x=df['amino_acid'], hue=df['location'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Alternatively, to answer part 'a' what will be helpful is to go to the website listed below, PDBsum and enter in your proteins PDB code. From there you can glean quite a bit of information about your protein.
# As you can see on the right hand corner of the top page, under procheck is the Ramachandran plot of the intended protein. Clicking on the image will open another tab in your browser, displaying the full plot and coordinates.

# %%
# %%HTML
# <iframe width = "800" height = "400" src="http://www.ebi.ac.uk/thornton-srv/databases/cgi-bin/pdbsum/GetPage.pl?pdbcode=2iv6&template=main.html" frameborder = "0" allowfullscreen></iframe>
# Out:
# <iframe width = "800" height = "400" src="http://www.ebi.ac.uk/thornton-srv/databases/cgi-bin/pdbsum/GetPage.pl?pdbcode=2iv6&template=main.html" frameborder = "0" allowfullscreen></iframe>

# %% [markdown]
# ##### Discussion
#
# The above program from Jupyter notebooks repository in GitHub walks us through detemining the angles and the dihedral angles associated with a chosen protein. From there, a histogram is generated, followed by a Ramachandran plot of our protein. Determinng the Ramachandran plot of a protein tells the researcher important structural elements. When looking at a traditional Ramachandran plot like in the PDBsum webpage above, the following definition for the specific areas describe what they mean, from this website https://www.cryst.bbk.ac.uk/PPS95/course/3_geometry/rama.html:
#
# "White areas correspond to conformations where atoms in the polypeptide come closer than the sum of their van der Waals radi. These regions are sterically disallowed for all amino acids except glycine which is unique in that it lacks a side chain. The red regions correspond to conformations where there are no steric clashes, ie these are the allowed regions namely the alpha-helical and beta-sheet conformations. The yellow areas show the allowed regions if slightly shorter van der Waals radi are used in the calculation, ie the atoms are allowed to come a little closer together. This brings out an additional region which corresponds to the left-handed alpha-helix."

# %% [markdown]
# #### 2.Pairwise sequence alignment and Multiple sequence alignment can be used to determine structure, which is the better option in the case of Nanog?
#
# a.	What parameters are needed for PSA to be used on certain protein sequences
#
# b.	What parameters are expected for MSA to be used for certain protein sequences.
#
# c.	Given the sequence to perform MSA or PSA, which online tools would be best to generate the alignment comparison data, CLUSTALW or MUSCLE? Or another tool?
#
# d.	How can we gather data from PDB or other sources to assist with the above tools to help distinguish structure?

# %% [markdown]
#     First, to determine which path to take, Mulitple Sequence Alignment (MSA) or Pairwise Sequence Alignment (PSA), the below comparison chart from this website (https://www.majordifferences.com/2016/05/difference-between-pairwise-and-multiple-sequence-alignment.html) will help in deciding which tools need to be used.

# %% [markdown]
# ![Screenshot%20%28158%29.png](attachment:Screenshot%20%28158%29.png)

# %% [markdown]
#     Within Pairwise Alignment there are also two other determining factors for analyzing a sequence, Local or Global alignment. Another useful chart (https://www.majordifferences.com/2016/05/difference-between-pairwise-and-multiple-sequence-alignment.html)below can help in deciding which path is best.

# %% [markdown]
# ![Screenshot%20%28159%29.png](attachment:Screenshot%20%28159%29.png)

# %% [markdown]
# ![Screenshot%20%28160%29.png](attachment:Screenshot%20%28160%29.png)

# %% [markdown]
# #### If the path chosen is PSA, use one of the below tools based on Global or Local alignment, following the instructions within the different databases.
#
# EMBOSS Needle (Global Alignment) - EMBOSS Needle creates an optimal global alignment of two sequences using the Needleman-Wunsch algorithm: https://www.ebi.ac.uk/Tools/psa/emboss_needle/
#
# EMBOSS Water (Local Alignment) - EMBOSS Water uses the Smith-Waterman algorithm (modified for speed enhancements) to calculate the local alignment of two sequences: https://www.ebi.ac.uk/Tools/psa/emboss_water/
#
# LALIGN (Local Alignment) - LALIGN finds internal duplications by calculating non-intersecting local alignments of protein or DNA sequences: https://www.ebi.ac.uk/Tools/psa/lalign/
#
# BLAST (Local Alignment) - finds regions of similarity between biological sequences. The program compares nucleotide or protein sequences to sequence databases and calculates the statistical significance: https://blast.ncbi.nlm.nih.gov/Blast.cgi

# %% [markdown]
# #### If the alignment method chosen is Multiple Sequence Alignment, use one of the below tools, following the instructions within the database.
#
# MUSCLE - Accurate MSA tool, especially good with proteins. Suitable for medium alignments: https://www.ebi.ac.uk/Tools/msa/muscle/
#
# T-Coffee - Consistency-based MSA tool that attempts to mitigate the pitfalls of progressive alignment methods. Suitable for small alignments: https://www.ebi.ac.uk/Tools/msa/tcoffee/
#
# MAFFT - MSA tool that uses Fast Fourier Transforms. Suitable for medium-large alignments: https://www.ebi.ac.uk/Tools/msa/mafft/
#
# Clustal Omega - New MSA tool that uses seeded guide trees and HMM profile-profile techniques to generate alignments. Suitable for medium-large alignments: https://www.ebi.ac.uk/Tools/msa/clustalo/

# %% [markdown]
# FAQ Help Pages for PSA and MSA using EMBL-EBI Databases:
# https://www.ebi.ac.uk/seqdb/confluence/display/JDSAT/Multiple+Sequence+Alignment
# https://www.ebi.ac.uk/seqdb/confluence/display/JDSAT/Pairwise+Sequence+Alignment

# %% [markdown]
# The first step of all the above alignment options is the Sequence Input Window. The input can be in FASTA format downloaded from the PDB website for the specific protein(s) of choice.
#
# PSA Window:
# ![Screenshot%20%28162%29.png](attachment:Screenshot%20%28162%29.png)

# %% [markdown]
# MSA Window:
# ![Screenshot%20%28161%29.png](attachment:Screenshot%20%28161%29.png)

# %% [markdown]
# The next steps are setting any parameters within the different tools in the Sequence Input Window and then submitting and viewing the alignments.
#
# All the different alignment tools listed above interpret data and analyze it a little differently, to know what the submission results are displaying the above links to the FAQ page will help determine what the anlaysis means.
#
# All the web links to every tool are accessed within the EMBL-EBI database, however some of the tools have their own websites or databases that can be found in the FAQ page.

# %% [markdown]
# #### 3.How can we link mutations and structural changes to the homeobox of Nanog with the effect on function?
# a.	How can MSA display evolutionary changes of the protein? Why is this useful?
#
# b.	How can mass spectroscopy data inform the function of Nanog?
#
# c.	What tools can be used to interpret protein sequence?
#
# d.	How does Prosite help with determining protein sequence?

# %% [markdown]
# To provide an answer to 3.a the MSA results in the submission page one of the tabs displays the plylogenetic tree of the sequences input for alignment. An example is below from running a MSA comparison using Nanog (2VI6), SOX2 (6WX7), and KLF4 (2WBS) using T-Coffee. The tree shows the evolutionary connection of the protein sequences with a similarity score. This is able to inform whether or how much a certain protein has changed in any way.
# ![Screenshot%20%28165%29.png](attachment:Screenshot%20%28165%29.png)

# %% [markdown]
# Another useful tool to display conservation is the Multiple Sequence Viewer within NCBI BLAST search results. The red hihlight the highly conserved regions of the protein, while the blue regions highlight the least conserved regions.

# %% [markdown]
# ![Screenshot%20%28177%29.png](attachment:Screenshot%20%28177%29.png)

# %% [markdown]
# One database useful for determining protein families and domains, for instance, searching for the homeobox domain, would be the Prosite website. Prosite houses protein families and domains, basing its structure on the observation that most proteins can be grouped based on similarties in sequences into limited number of families. Proteins or protein domains belonging to a particular family generally share functional attributes and are derived from a common ancestor. The PROSITE home page is below, input the protein in the seach bar or the FASTA sequence or UniProtKB accession in the Quick Scan mode and submit.

# %%
# %%HTML
# <iframe width = "1000" height = "400" src="https://prosite.expasy.org/prosite.html" frameborder = "0" allowfullscreen></iframe>
# Out:
# <iframe width = "1000" height = "400" src="https://prosite.expasy.org/prosite.html" frameborder = "0" allowfullscreen></iframe>

# %% [markdown]
# #### After submitting the protein of choice, in this tutorial its 2VI6, the below image is displayed, highlighting the protein homoebox domain. This image displays the hits by profile
#
# ![Screenshot%20%28163%29.png](attachment:Screenshot%20%28163%29.png)

# %% [markdown]
# #### While this image displays the hits by pattern, although both indicate the only protein domain is the homeobox in the given protein sequence.
#
# ![Screenshot%20%28164%29.png](attachment:Screenshot%20%28164%29.png)

# %% [markdown]
# #### PROSITE links the domain information pages and users can click on them to learn more about the domains or families in the input protein/sequence. Below is the information for 2VI6 homeobox domain.

# %%
# %%HTML
# <iframe width = "1000" height = "400" src="https://prosite.expasy.org/cgi-bin/prosite/nicedoc.pl?PS50071" frameborder = "0" allowfullscreen></iframe>
# Out:
# <iframe width = "1000" height = "400" src="https://prosite.expasy.org/cgi-bin/prosite/nicedoc.pl?PS50071" frameborder = "0" allowfullscreen></iframe>

# %% [markdown]
# Homedomains (HD) are evolutionarily conserved DNA-binding motifs that are found in a variety of proteins involved in profound developmental decisions per the paper by Jauch, R. et al. (2008). The paper also states "Despite containing a glutamine at position 50, Nanog has been referred to as a variant HD protein based on its relatively low degree of overall sequence conservation." The above description of the typical homeodomain points out the difference the paper indicated comopared to how normally a homeodomain is essentially a very evolutionary conserved region. Further the paper explains "The amino acid sequence of the Nanog HD was found to be 50% identical with members of the NK-2 family of HDs, and Nanog has thus been referred to as a distant member of this family. NK-2-type HDs, however, bind to an uncommon C1A2A3G4X5X6 sequence. Given the pronounced impact of a loss of Nanog on early mammalian development and its versatile regulatory potential, the as yet unknown molecular details of the action of the full-length Nanog and particularly of its DNA binding domain are of fundamental interest."
#
#
# Reference:
# Ralf Jauch, Calista Keow Leng Ng, Kumar Singh Saikatendu, Raymond C. Stevens, Prasanna R. Kolatkar, Crystal Structure and DNA Binding of the Homeodomain of the Stem Cell Transcription Factor Nanog, Journal of Molecular Biology, Volume 376, Issue 3, 2008, Pages 758-770, ISSN 0022-2836, https://doi.org/10.1016/j.jmb.2007.11.091.

# %% [markdown]
# #### 4.How can Position Specific mutations, such as deletions or insertions in a sequence change the function of a protein?
# a.	How can Position Specific Scoring Matrices be used?
#
# b.	What experiments could be performed using Nanog to identify position mutations related to function?
#
# c.	What information can be gleaned from compositional biases in relation to protein function or localization?
#
# d.	What type of mutations can change function? Do they all cause a reaction?

# %% [markdown]
# First, let's go over and define what Position Specific Scoring Matrices (PSSMs) are. A paper by Beckstette, M. et al. (2006) PSSM is describes as "In biological sequence analysis, position specific scoring matrices (PSSMs) are widely used to represent sequence motifs in nucleotide as well as amino acid sequences. Searching with PSSMs in complete genomes or large sequence databases is a common, but computationally expensive task." This method is useful for comparing a target sequence against others to determine differences such as mutations within a sequence. Addtionally, another document from Virginia Commonwealth University continues with "The PSSM gives us a tool to score how close any sequence is to the collected sequences used to create the scoring matrix (also called the training sequences). You would expect that a sequence close to the training sequences would tend to have higher scores at each position. The total score, i.e. the product of the scores at each position, should be higher that of most other sequences of similar length."
#
# Knowledge-based PSSM can be obtained from various transcription factor databases, for example:
#
# PSI-Blast (NCBI)
#
# JASPAR (Eukaryotes)
#
# RegulonDB (Escherichia coli K12)
#
# SCPD (The Promoter Database of Saccharomcyces cerevisiae)
#
# Yeastract (Yeast Search for Transcriptional Regulators And Consensus Tracking)
#
#
# References:
#
# Beckstette, M., Homann, R., Giegerich, R. et al. Fast index based algorithms and software for matching position specific scoring matrices. BMC Bioinformatics 7, 389 (2006). https://doi.org/10.1186/1471-2105-7-389
#
# http://www.people.vcu.edu/~elhaij/IntroBioinf/Notes/PSSM.pdf
#
# https://rsat01.biologie.ens.fr/rsa-tools/tutorials/tut_PSSM.html

# %% [markdown]
#     For ease of use, an example of using PSI-Blast through EMBL-EBI is displayed below using Nanog, as a type of experiment to discover PSSMs. The image depicts the 5th iteration of PSI-Blast and the protein sequence best match based on E-value with a cutoff threshold of 5e-3.
#
#     The steps to use EMBL PSI-Blast are the same as above, in the first window input the protein sequence and then set any parameters specific to the sequence of interest, following submit the job and wait for it to complete.
#
#     To note, PSI-Blast is available onEMBLE-EBI, as well as directly through NCBI website, this page (https://www.ncbi.nlm.nih.gov/books/NBK2590/) on NCBI walk through how to cunduct and submit a PSI-Blast job.

# %% [markdown]
# ![Screenshot%20%28166%29.png](attachment:Screenshot%20%28166%29.png)

# %% [markdown]
# Compositional Bias is defined as follows from NCBI "Compositional bias is defined as the presence of low entropy, or low information content in a protein sequence. Typically, such a sequence may be marked by enrichment of the sequence in particular amino acids, homopolymeric stretches of a particular amino acid or presence of short-range repetitive structures such as coiled-coils or short β-helices."
#
# https://www.ncbi.nlm.nih.gov/books/NBK2590/

# %% [markdown]
# There are multiple different types of mutations which can effect the function of a protein, however other mutations have no effect at all. Below are definitions of some of these effects from MedlinePlus.
#
# Substitution
#
# This type of variant replaces one DNA building block (nucleotide) with another. Substitution variants can be further classified by the effect they have on the production of protein from the altered gene.
#
# Missense: A missense variant  is a type of substitution in which the nucleotide change results in the replacement of one protein building block (amino acid) with another in the protein made from the gene. The amino acid change may alter the function of the protein.
#
# Nonsense: A nonsense variant  is another type of substitution. Instead of causing a change in one amino acid, however, the altered DNA sequence results in a stop signal that prematurely signals the cell to stop building a protein. This type of variant results in a shortened protein that may function improperly, be nonfunctional, or get broken down.
# Insertion
#
# An insertion changes the DNA sequence by adding one or more nucleotides to the gene. As a result, the protein made from the gene may not function properly.
#
# Deletion
#
# A deletion changes the DNA sequence by removing at least one nucleotide in a gene. Small deletions remove one or a few nucleotides within a gene, while larger deletions can remove an entire gene or several neighboring genes. The deleted DNA may alter the function of the affected protein or proteins.
#
#
# Additional definitions can be found here:
#
# https://medlineplus.gov/genetics/understanding/mutationsanddisorders/possiblemutations/#:~:text=A%20deletion%20changes%20the%20DNA,the%20affected%20protein%20or%20proteins.

# %% [markdown]
# ### Final Discussion
#
# This project is.....
